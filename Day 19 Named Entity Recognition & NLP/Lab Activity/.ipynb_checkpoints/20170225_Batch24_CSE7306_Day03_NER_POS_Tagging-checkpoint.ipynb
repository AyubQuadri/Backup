# %%
import os
# os.getcwd()
# os.chdir("C:\Users\quadris\Desktop\My Learning\INSOFE CPEE\Day 19\Lab Activity")
os.getcwd()
# Out:
# 'C:\\Users\\quadris\\Desktop\\My Learning\\INSOFE CPEE\\Day 19\\Lab Activity'

# %%
os.chdir("C:\Users\quadris\Desktop\My Learning\INSOFE CPEE\Day 19\Lab Activity")

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '20170225_Batch24_CSE7306_Day03_NER_POS_Tagging.ipynb',
#  'ExcerciseData.txt']

# %%
with open('ExcerciseData.txt', 'r') as myfile:
    data=myfile.read().replace('\n',' ').split(".") #Separated the sentences 

type(data)
print(data)
# Out:
# ['abdn', 'ac', 'uk\ttay', 'ac', 'uk\t684', '7\t4', '\t231', '\t', '7\t6 abdn', 'ac', 'uk\tanglia', 'ac', 'uk\t684', '7\t4', '\t722', '2\t', '5\t3 abdn', 'ac', 'uk\taston', 'ac', 'uk\t684', '7\t4', '\t265', '9\t3', '8\t3 abdn', 'ac', 'uk\tbath', 'ac', 'uk\t684', '7\t4', '\t480', '3\t5', '2\t41 abdn', 'ac', 'uk\tbathspa', 'ac', 'uk\t684', '7\t4', '\t164', '\t1', '5\t0 abdn', 'ac', 'uk\tbham', 'ac', 'uk\t684', '7\t4', '\t1381', '9\t4', '3\t321 abdn', 'ac', 'uk\tbournemouth', 'ac', 'uk\t684', '7\t4', '\t387', '3\t', '7\t10 abdn', 'ac', 'uk\tbrad', 'ac', 'uk\t684', '7\t4', '\t432', '5\t3', '3\t4 abdn', 'ac', 'uk\tbton', 'ac', 'uk\t684', '7\t4', '\t605', '9\t1', '7\t5 abdn', 'ac', 'uk\tbris', 'ac', 'uk\t684', '7\t4', '\t1169', '7\t5', '2\t88 abdn', 'ac', 'uk\tbrunel', 'ac', 'uk\t684', '7\t4', '\t550', '5\t3', '1\t20 abdn', 'ac', 'uk\tbuckingham', 'ac', 'uk\t684', '7\t4', '\t339', '3\t', '8\t0 abdn', 'ac', 'uk\tcam', 'ac', 'uk\t684', '7\t4', '\t1892', '5\t6', '5\t202 abdn', 'ac', 'uk\tcant', 'ac', 'uk\t684', '7\t4', '\t265', '6\t1', '1\t0 abdn', 'ac', 'uk\tchichester', 'ac', 'uk\t684', '7\t4', '\t155', '1\t1', '7\t0 abdn', 'ac', 'uk\tcranfield', 'ac', 'uk\t684', '7\t4', '\t443', '3\t2', '6\t10 abdn', 'ac', 'uk\tuce', 'ac', 'uk\t684', '7\t4', '\t680', '9\t', '8\t2 abdn', 'ac', 'uk\tuclan', 'ac', 'uk\t684', '7\t4', '\t796', '6\t', '9\t1 abdn', 'ac', 'uk\tcity', 'ac', 'uk\t684', '7\t4', '\t347', '2\t3', '7\t6 abdn', 'ac', 'uk\tcoventry', 'ac', 'uk\t684', '7\t4', '\t625', '8\t1', '\t3 abdn', 'ac', 'uk\tderby', 'ac', 'uk\t684', '7\t4', '\t445', '\t', '9\t4 abdn', 'ac', 'uk\tdundee', 'ac', 'uk\t684', '7\t4', '\t595', '1\t4', '2\t108 abdn', 'ac', 'uk\tdur', 'ac', 'uk\t684', '7\t4', '\t696', '4\t5', '2\t45 abdn', 'ac', 'uk\tuea', 'ac', 'uk\t684', '7\t4', '\t473', '\t5', '\t29 abdn', 'ac', 'uk\tuel', 'ac', 'uk\t684', '7\t4', '\t523', '5\t1', '4\t4 abdn', 'ac', 'uk\ted', 'ac', 'uk\t684', '7\t4', '\t1623', '9\t5', '\t301 abdn', 'ac', 'uk\tessex', 'ac', 'uk\t684', '7\t4', '\t398', '2\t4', '8\t25 abdn', 'ac', 'uk\tex', 'ac', 'uk\t684', '7\t4', '\t547', '7\t4', '7\t32 abdn', 'ac', 'uk\tgcal', 'ac', 'uk\t684', '7\t4', '\t616', '7\t1', '2\t15 abdn', 'ac', 'uk\tglam', 'ac', 'uk\t684', '7\t4', '\t458', '9\t1', '3\t4 abdn', 'ac', 'uk\tgla', 'ac', 'uk\t684', '7\t4', '\t1386', '9\t4', '2\t151 abdn', 'ac', 'uk\tgre', 'ac', 'uk\t684', '7\t4', '\t767', '6\t1', '2\t2 abdn', 'ac', 'uk\tlgu', 'ac', 'uk\t684', '7\t4', '\t418', '7\t', '8\t8 abdn', 'ac', 'uk\tharper-adams', 'ac', 'uk\t684', '7\t4', '\t100', '\t-1', '\t2 abdn', 'ac', 'uk\thw', 'ac', 'uk\t684', '7\t4', '\t398', '9\t4', '2\t182 abdn', 'ac', 'uk\therts', 'ac', 'uk\t684', '7\t4', '\t692', '2\t1', '4\t6 abdn', 'ac', 'uk\thud', 'ac', 'uk\t684', '7\t4', '\t578', '7\t', '9\t3 abdn', 'ac', 'uk\thull', 'ac', 'uk\t684', '7\t4', '\t535', '3\t3', '2\t11 abdn', 'ac', 'uk\tkeele', 'ac', 'uk\t684', '7\t4', '\t444', '3\t4', '\t19 abdn', 'ac', 'uk\tukc', 'ac', 'uk\t684', '7\t4', '\t439', '4\t4', '\t29 abdn', 'ac', 'uk\tking', 'ac', 'uk\t684', '7\t4', '\t532', '8\t1', '2\t3 abdn', 'ac', 'uk\tlancs', 'ac', 'uk\t684', '7\t4', '\t518', '2\t5', '4\t23 abdn', 'ac', 'uk\tleeds', 'ac', 'uk\t684', '7\t4', '\t1472', '7\t4', '5\t250 abdn', 'ac', 'uk\tlmu', 'ac', 'uk\t684', '7\t4', '\t692', '9\t', '8\t3 abdn', 'ac', 'uk\tle', 'ac', 'uk\t684', '7\t4', '\t788', '1\t4', '5\t55 abdn', 'ac', 'uk\tdmu', 'ac', 'uk\t684', '7\t4', '\t1188', '5\t1', '4\t12 abdn', 'ac', 'uk\tulh', 'ac', 'uk\t684', '7\t4', '\t349', '7\t', '7\t1 abdn', 'ac', 'uk\tliv', 'ac', 'uk\t684', '7\t4', '\t972', '2\t4', '6\t199 abdn', 'ac', 'uk\tlivjm', 'ac', 'uk\t684', '7\t4', '\t820', '1\t1', '2\t7 abdn', 'ac', 'uk\tgoldsmiths', 'ac', 'uk\t684', '7\t4', '\t280', '7\t4', '9\t5 abdn', 'ac', 'uk\tic', 'ac', 'uk\t684', '7\t4', '\t1340', '4\t5', '8\t90 abdn', 'ac', 'uk\tkcl', 'ac', 'uk\t684', '7\t4', '\t1448', '6\t4', '7\t20 abdn', 'ac', 'uk\tqmw', 'ac', 'uk\t684', '7\t4', '\t753', '3\t4', '7\t19 abdn', 'ac', 'uk\trhul', 'ac', 'uk\t684', '7\t4', '\t383', '2\t5', '2\t10 ...

# %%
print(data[1])
print(data[2])
type(data[2])
# Out:
# ac
# uk	tay
# str

# %%
import nltk
import time
import nltk.tokenize

# Creating a list with a sentence
data1 = [data[2]]
print(data1)
# Out:
# [' On hearing an inspired sermon by the Reverend Richard Allen, founder of the Bethel African Methodist Episcopal Church, Lee joined the Methodists']

# %%
# Tokenizing the sentence
for item in data1:
    tokenized = nltk.word_tokenize(item)
    print(tokenized)
# Out:
# ['On', 'hearing', 'an', 'inspired', 'sermon', 'by', 'the', 'Reverend', 'Richard', 'Allen', ',', 'founder', 'of', 'the', 'Bethel', 'African', 'Methodist', 'Episcopal', 'Church', ',', 'Lee', 'joined', 'the', 'Methodists']

# %%
# Binding the parts of speech to the tokens
for item in data1:
    tokenized = nltk.word_tokenize(item)
    tagged = nltk.pos_tag(tokenized)
    print tagged
    # Retrieving the parts of speech tags
    tags = [b[1] for b in tagged]
    print tags
    # Getting the frequency of POS tags
    fd = nltk.FreqDist(tags)
    fd.tabulate()
# Out:
# [('On', 'IN'), ('hearing', 'VBG'), ('an', 'DT'), ('inspired', 'JJ'), ('sermon', 'NN'), ('by', 'IN'), ('the', 'DT'), ('Reverend', 'NNP'), ('Richard', 'NNP'), ('Allen', 'NNP'), (',', ','), ('founder', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Bethel', 'NNP'), ('African', 'NNP'), ('Methodist', 'NNP'), ('Episcopal', 'NNP'), ('Church', 'NNP'), (',', ','), ('Lee', 'NNP'), ('joined', 'VBD'), ('the', 'DT'), ('Methodists', 'NNS')]
# ['IN', 'VBG', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NNP', 'NNP', 'NNP', ',', 'NN', 'IN', 'DT', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', ',', 'NNP', 'VBD', 'DT', 'NNS']
# NNP  DT  IN  NN   , VBG VBD  JJ NNS
#   9   4   3   2   2   1   1   1   1

# %%
# Defining the customized parsers
#grammar = "NP: {<DT>?<JJ>*<NN>}"
#cp = nltk.RegexpParser(grammar)
#result = cp.parse(tagged)
#print(result)
#result.draw()

# %%
# Creating the Named Entity Anotators
for item in data1:
    tokenized = nltk.word_tokenize(item)
    tagged = nltk.pos_tag(tokenized)
    namedEnt = nltk.ne_chunk(tagged,binary=False)
    print namedEnt
# Out:
# (S
#   On/IN
#   hearing/VBG
#   an/DT
#   inspired/JJ
#   sermon/NN
#   by/IN
#   the/DT
#   (ORGANIZATION Reverend/NNP)
#   (PERSON Richard/NNP Allen/NNP)
#   ,/,
#   founder/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Bethel/NNP African/NNP)
#   (ORGANIZATION Methodist/NNP Episcopal/NNP Church/NNP)
#   ,/,
#   (PERSON Lee/NNP)
#   joined/VBD
#   the/DT
#   (ORGANIZATION Methodists/NNS))

# %%
# Printing the Names of the preson and POS tag based on the entity Person
for item in data1:
    tokenized = nltk.word_tokenize(item)
    tagged = nltk.pos_tag(tokenized)
    namedEnt = nltk.ne_chunk(tagged,binary=False)
    for x in namedEnt.subtrees():
        if x.label() == "PERSON": 
            print x
            for y in x.leaves(): 
                print len(y)
                print y[0]
                print y[1]
# Out:
# (PERSON Richard/NNP Allen/NNP)
# 2
# Richard
# NNP
# 2
# Allen
# NNP
# (PERSON Lee/NNP)
# 2
# Lee
# NNP

# %%
# Printing the names of the persons from the sentences
np_person1=[]

for item in data1:
    tokenized = nltk.word_tokenize(item)
    tagged = nltk.pos_tag(tokenized)
    namedEnt = nltk.ne_chunk(tagged,binary=False)
    np_person1.append([' '.join([y[0] for y in x.leaves()]) for x in namedEnt.subtrees() if x.label() == "PERSON"])
    namedEnt.draw()
    print np_person1
# Out:
# [['Richard Allen', 'Lee']]

# %%
import nltk
import time
import nltk.tokenize
#from nltk.tokenize import PunktSentenceTokenizer
#from nltk.tag import StanfordNERTagger

def processLanguage():
    np_person=[]
    try:
        for item in data:
            tokenized = nltk.word_tokenize(item)
            tagged = nltk.pos_tag(tokenized)
            print tagged

            namedEnt = nltk.ne_chunk(tagged,binary=False)
            print namedEnt         
            np_person.append([' '.join([y[0] for y in x.leaves()]) for x in namedEnt.subtrees() if x.label() == "PERSON"])
            namedEnt.draw()
            time.sleep(1)
       
    except Exception, e:
        print str(e)
    print np_person

# %%
processLanguage()
# Out:
# [('In', 'IN'), ('1804', 'CD'), (',', ','), ('after', 'IN'), ('several', 'JJ'), ('months', 'NNS'), ('of', 'IN'), ('profound', 'JJ'), ('spiritual', 'JJ'), ('anxiety', 'NN'), (',', ','), ('Jarena', 'NNP'), ('Lee', 'NNP'), ('moved', 'VBD'), ('from', 'IN'), ('New', 'NNP'), ('Jersey', 'NNP'), ('to', 'TO'), ('Philadelphia', 'NNP')]
# (S
#   In/IN
#   1804/CD
#   ,/,
#   after/IN
#   several/JJ
#   months/NNS
#   of/IN
#   profound/JJ
#   spiritual/JJ
#   anxiety/NN
#   ,/,
#   (PERSON Jarena/NNP Lee/NNP)
#   moved/VBD
#   from/IN
#   (GPE New/NNP Jersey/NNP)
#   to/TO
#   (GSP Philadelphia/NNP))
# [('There', 'EX'), ('she', 'PRP'), ('labored', 'VBD'), ('as', 'IN'), ('a', 'DT'), ('domestic', 'JJ'), ('and', 'CC'), ('worshiped', 'VBD'), ('among', 'IN'), ('white', 'JJ'), ('congregations', 'NNS'), ('of', 'IN'), ('Roman', 'NNP'), ('Catholics', 'NNPS'), ('and', 'CC'), ('mixed', 'JJ'), ('congregations', 'NNS'), ('of', 'IN'), ('Methodists', 'NNS')]
# (S
#   There/EX
#   she/PRP
#   labored/VBD
#   as/IN
#   a/DT
#   domestic/JJ
#   and/CC
#   worshiped/VBD
#   among/IN
#   white/JJ
#   congregations/NNS
#   of/IN
#   (ORGANIZATION Roman/NNP Catholics/NNPS)
#   and/CC
#   mixed/JJ
#   congregations/NNS
#   of/IN
#   (ORGANIZATION Methodists/NNS))
# [('On', 'IN'), ('hearing', 'VBG'), ('an', 'DT'), ('inspired', 'JJ'), ('sermon', 'NN'), ('by', 'IN'), ('the', 'DT'), ('Reverend', 'NNP'), ('Richard', 'NNP'), ('Allen', 'NNP'), (',', ','), ('founder', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Bethel', 'NNP'), ('African', 'NNP'), ('Methodist', 'NNP'), ('Episcopal', 'NNP'), ('Church', 'NNP'), (',', ','), ('Lee', 'NNP'), ('joined', 'VBD'), ('the', 'DT'), ('Methodists', 'NNS')]
# (S
#   On/IN
#   hearing/VBG
#   an/DT
#   inspired/JJ
#   sermon/NN
#   by/IN
#   the/DT
#   (ORGANIZATION Reverend/NNP)
#   (PERSON Richard/NNP Allen/NNP)
#   ,/,
#   founder/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Bethel/NNP African/NNP)
#   (ORGANIZATION Methodist/NNP Episcopal/NNP Church/NNP)
#   ,/,
#   (PERSON Lee/NNP)
#   joined/VBD
#   the/DT
#   (ORGANIZATION Methodists/NNS))
# [('She', 'PRP'), ('was', 'VBD'), ('baptized', 'VBN'), ('in', 'IN'), ('1807', 'CD')]
# (S She/PRP was/VBD baptized/VBN in/IN 1807/CD)
# [('Prior', 'RB'), ('to', 'TO'), ('her', 'PRP$'), ('baptism', 'NN'), (',', ','), ('she', 'PRP'), ('experienced', 'VBD'), ('the', 'DT'), ('various', 'JJ'), ('physical', 'JJ'), ('and', 'CC'), ('emotional', 'JJ'), ('stages', 'NNS'), ('of', 'IN'), ('conversion', 'NN'), (':', ':'), ('terrifying', 'JJ'), ('visions', 'NNS'), ('of', 'IN'), ('demons', 'NNS'), ('and', 'CC'), ('eternal', 'JJ'), ('perdition', 'NN'), (';', ':'), ('extreme', 'JJ'), ('feelings', 'NNS'), ('of', 'IN'), ('ecstasy', 'NN'), ('and', 'CC'), ('depression', 'NN'), (';', ':'), ('protracted', 'VBN'), ('periods', 'NNS'), ('of', 'IN'), ('meditation', 'NN'), (',', ','), ('fasting', 'NN'), (',', ','), ('and', 'CC'), ('prayer', 'NN'), (';', ':'), ('ennui', 'CC'), ('and', 'CC'), ('fever', 'NN'), (';', ':'), ('energy', 'NN'), ('and', 'CC'), ('vigor', 'NN')]
# (S
#   Prior/RB
#   to/TO
#   her/PRP$
#   baptism/NN
#   ,/,
#   she/PRP
#   experienced/VBD
#   the/DT
#   various/JJ
#   physical/JJ
#   and/CC
#   emotional/JJ
#   stages/NNS
#   of/IN
#   conversion/NN
#   :/:
#   terrifying/JJ
#   visions/NNS
#   of/IN
#   demons/NNS
#   and/CC
#   eternal/JJ
#   perdition/NN
#   ;/:
#   extreme/JJ
#   feelings/NNS
#   of/IN
#   ecstasy/NN
#   and/CC
#   depression/NN
#   ;/:
#   protracted/VBN
#   periods/NNS
#   of/IN
#   meditation/NN
#   ,/,
#   fasting/NN
#   ,/,
#   and/CC
#   prayer/NN
#   ;/:
#   ennui/CC
#   and/CC
#   fever/NN
#   ;/:
#   energy/NN
#   and/CC
#   vigor/NN)
# [('In', 'IN'), ('1811', 'CD'), ('she', 'PRP'), ('married', 'VBD'), ('Joseph', 'NNP'), ('Lee', 'NNP'), (',', ','), ('who', 'WP'), ('pastored', 'VBD'), ('an', 'DT'), ('African-American', 'JJ'), ('church', 'NN'), ('in', 'IN'), ('Snow', 'NNP'), ('Hill', 'NNP'), (',', ','), ('New', 'NNP'), ('Jersey', 'NNP')]
# (S
#   In/IN
#   1811/CD
#   she/PRP
#   married/VBD
#   (PERSON Joseph/NNP Lee/NNP)
#   ,/,
#   who/WP
#   pastored/VBD
#   an/DT
#   African-American/JJ
#   church/NN
#   in/IN
#   (GPE Snow/NNP Hill/NNP)
#   ,/,
#   (GPE New/NNP Jersey/NNP))
# [('They', 'PRP'), ('had', 'VBD'), ('six', 'CD'), ('children', 'NNS'), (',', ','), ('four', 'CD'), ('of', 'IN'), ('whom', 'WP'), ('died', 'VBD'), ('in', 'IN'), ('infancy', 'NN')]
# (S
#   They/PRP
#   had/VBD
#   six/CD
#   children/NNS
#   ,/,
#   four/CD
#   of/IN
#   whom/WP
#   died/VBD
#   in/IN
#   infancy/NN)
# []
# (S )
# [['Jarena Lee'], [], ['Richard Allen', 'Lee'], [], [], ['Joseph Lee'], [], []]
